# %% [markdown]
# # Dealing with Categorical Variables - Lab

# %% [markdown]
# ## Introduction
# In this lab, you'll explore the Boston Housing Data Set for categorical variables, and you'll transform your data so you'll be able to use categorical data as predictors!

# %% [markdown]
# ## Objectives
# You will be able to:
# * Identify and inspect the categorical variables in the Boston housing data set
# * Learn how to categorize inputs that aren't categorical
# * Create new datasets with dummy variables

# %% [markdown]
# ## Importing the Boston Housing data set

# %% [markdown]
# Let's start by importing the Boston Housing data set. This data set is available in Scikit-Learn, and can be imported running the column below.

# %%
import pandas as pd
from sklearn.datasets import load_boston
boston = load_boston()

# %% [markdown]
# If you'll inspect Boston now, you'll see that this basically returns a dictionary. Let's have a look at what exactly is stored in the dictionary by looking at the dictionary keys

# %%
# inspect boston
boston
# Out:
# {'data': array([[6.3200e-03, 1.8000e+01, 2.3100e+00, ..., 1.5300e+01, 3.9690e+02,
#          4.9800e+00],
#         [2.7310e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9690e+02,
#          9.1400e+00],
#         [2.7290e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9283e+02,
#          4.0300e+00],
#         ...,
#         [6.0760e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#          5.6400e+00],
#         [1.0959e-01, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9345e+02,
#          6.4800e+00],
#         [4.7410e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#          7.8800e+00]]),
#  'target': array([24. , 21.6, 34.7, 33.4, 36.2, 28.7, 22.9, 27.1, 16.5, 18.9, 15. ,
#         18.9, 21.7, 20.4, 18.2, 19.9, 23.1, 17.5, 20.2, 18.2, 13.6, 19.6,
#         15.2, 14.5, 15.6, 13.9, 16.6, 14.8, 18.4, 21. , 12.7, 14.5, 13.2,
#         13.1, 13.5, 18.9, 20. , 21. , 24.7, 30.8, 34.9, 26.6, 25.3, 24.7,
# ...

# %%
# look at the keys
boston.keys()
# Out:
# dict_keys(['data', 'target', 'feature_names', 'DESCR', 'filename'])

# %% [markdown]
# Let's create a Pandas DataFrame with the data (which are the features, not including the target) and the feature names as column names.

# %%
boston_features = pd.DataFrame(boston['data'], columns=boston['feature_names'])

# %%
#inspect the first few rows
boston_features.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %% [markdown]
# For your reference, we copied the attribute information below. Additional information can be found here: http://scikit-learn.org/stable/datasets/index.html#boston-dataset
# - CRIM: per capita crime rate by town
# - ZN: proportion of residential land zoned for lots over 25,000 sq.ft.
# - INDUS: proportion of non-retail business acres per town
# - CHAS: Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
# - NOX: nitric oxides concentration (parts per 10 million)
# - RM: average number of rooms per dwelling
# - AGE: proportion of owner-occupied units built prior to 1940
# - DIS: weighted distances to five Boston employment centres
# - RAD: index of accessibility to radial highways
# - TAX: full-value property-tax rate per $10,000
# - PTRATIO: pupil-teacher ratio by town
# - B: 1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town
# - LSTAT: % lower status of the population

# %% [markdown]
# Let's convert the target to a dataframe as well, and assign the column name "MEDV"

# %%
boston_target = pd.DataFrame(boston['target'], columns=['MEDV'])

#inspect the first few rows
boston_target.head()
# Out:
#    MEDV
# 0  24.0
# 1  21.6
# 2  34.7
# 3  33.4
# 4  36.2

# %% [markdown]
# The target is described as:
# - MEDV: Median value of owner-occupied homes in $1000’s

# %% [markdown]
# Next, let's merge the target and the predictors in one dataframe `boston_df`.

# %%
boston_df = boston_target.merge(boston_features, right_index=True, left_index=True)
boston_df.head()
# Out:
#    MEDV     CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  24.0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  21.6  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  34.7  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  33.4  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  36.2  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %% [markdown]
# Let's inspect these 13 features using `.describe()` and `.info()`

# %%
# code here
print(boston_df.describe())
print("----------------------------------------")
# code here
boston_df.info()
# Out:
#              MEDV        CRIM          ZN       INDUS        CHAS         NOX  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    22.532806    3.613524   11.363636   11.136779    0.069170    0.554695
# std      9.197104    8.601545   23.322453    6.860353    0.253994    0.115878
# min      5.000000    0.006320    0.000000    0.460000    0.000000    0.385000
# 25%     17.025000    0.082045    0.000000    5.190000    0.000000    0.449000
# 50%     21.200000    0.256510    0.000000    9.690000    0.000000    0.538000
# 75%     25.000000    3.677083   12.500000   18.100000    0.000000    0.624000
# max     50.000000   88.976200  100.000000   27.740000    1.000000    0.871000
#
#                RM         AGE         DIS         RAD         TAX     PTRATIO  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     6.284634   68.574901    3.795043    9.549407  408.237154   18.455534
# ...

# %% [markdown]
# Now, take a look at the scatter plots for each predictor with the target on the y-axis.

# %%
boston_features.columns[0:4]
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS'], dtype='object')

# %%
import pandas as pd
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(20, 4))
axes = fig.subplots(nrows=1, ncols=4)
# create scatter plots
for feature, ax in zip(boston_features.columns[0:4], axes):
    ax.scatter(boston_features[feature], boston_target, color="#6427F8")
    ax.set_title(feature)

# %%
fig = plt.figure(figsize=(20, 4))
axes = fig.subplots(nrows=1, ncols=4)

for feature, ax in zip(boston_features.columns[4:8], axes):
    ax.scatter(boston_features[feature], boston_target, color="blue")
    ax.set_title(feature)

# %%
fig = plt.figure(figsize=(20, 4))
axes = fig.subplots(nrows=1, ncols=5)

for feature, ax in zip(boston_features.columns[8:13], axes):
    ax.scatter(boston_features[feature], boston_target, color="#668899")
    ax.set_title(feature)

# %% [markdown]
# ## To categorical: binning

# %% [markdown]
# If you created your scatterplots correctly, you'll notice that except for CHAS (the Charles River Dummy variable), there is no clearly categorical data. You will have seen though that RAD and TAX have more of a vertical-looking structure like the one seen in the lesson, and that there is less of a "cloud"-looking structure compared to most other variables. It is difficult to justify a linear pattern between predictor and target here. In this situation, it might make sense to restructure data into bins so that they're treated as categorical variables. We'll start by showing how this can be done for RAD and then it's your turn to do this for TAX.

# %% [markdown]
# ### "RAD"

# %% [markdown]
# Look at the structure of "RAD" to decide how to create your bins.

# %%
boston_df["RAD"].describe()
# Out:
# count    506.000000
# mean       9.549407
# std        8.707259
# min        1.000000
# 25%        4.000000
# 50%        5.000000
# 75%       24.000000
# max       24.000000
# Name: RAD, dtype: float64

# %%
# first, create bins for based on the values observed. 5 values will result in 4 bins
bins = [0, 3, 4 , 5, 24]
# use pd.cut
bins_rad = pd.cut(boston_df['RAD'], bins)

# %%
# using pd.cut returns unordered categories. Transform this to ordered categories.
bins_rad = bins_rad.cat.as_ordered()
bins_rad.head()
# Out:
# 0    (0, 3]
# 1    (0, 3]
# 2    (0, 3]
# 3    (0, 3]
# 4    (0, 3]
# Name: RAD, dtype: category
# Categories (4, interval[int64]): [(0, 3] < (3, 4] < (4, 5] < (5, 24]]

# %%
# inspect the result
bins_rad.value_counts().plot(kind='bar')

# %%
# replace the existing "RAD" column
boston_df["RAD"]=bins_rad
boston_df.head()
# Out:
#    MEDV     CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS     RAD  \
# 0  24.0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  (0, 3]
# 1  21.6  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  (0, 3]
# 2  34.7  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  (0, 3]
# 3  33.4  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  (0, 3]
# 4  36.2  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  (0, 3]
#
#      TAX  PTRATIO       B  LSTAT
# 0  296.0     15.3  396.90   4.98
# 1  242.0     17.8  396.90   9.14
# 2  242.0     17.8  392.83   4.03
# 3  222.0     18.7  394.63   2.94
# 4  222.0     18.7  396.90   5.33

# %% [markdown]
# ### "TAX"

# %% [markdown]
# Split the "TAX" column up in 5 categories. You can chose the bins as desired but make sure they're pretty well-balanced.

# %%
boston_df.TAX.describe()
# Out:
# count    506.000000
# mean     408.237154
# std      168.537116
# min      187.000000
# 25%      279.000000
# 50%      330.000000
# 75%      666.000000
# max      711.000000
# Name: TAX, dtype: float64

# %%
# repeat everything for "TAX"
boston_df.TAX.describe()
bins = [0, 250, 350, 500, 720]
tax_bin = pd.cut(boston_df.TAX, bins)
tax_bin.describe()
tax_bin.cat.as_ordered()
tax_bin.value_counts().plot(kind='bar')
boston_df["TAX"] = tax_bin

# %% [markdown]
# ## Perform label encoding

# %%
# perform label encoding and replace in boston_df
boston_df.TAX = boston_df.TAX.cat.codes
boston_df.RAD = boston_df.RAD.cat.codes

# %%
# inspect first few columns
boston_df.head()
# Out:
#    MEDV     CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0  24.0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    0    1
# 1  21.6  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    0    0
# 2  34.7  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    0    0
# 3  33.4  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    0    0
# 4  36.2  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    0    0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %% [markdown]
# ## Create dummy variables

# %% [markdown]
# Create dummy variables, and make sure their column names contain "TAX" and "RAD". Add the new dummy variables to boston_df and remove the old "RAD" and "TAX" columns.

# %%
# code goes here
TAX_dum = pd.get_dummies(tax_bin, prefix="TAX")
RAD_dum = pd.get_dummies(bins_rad, prefix="RAD")

# %%
boston_df.drop(columns=["RAD"])
boston_df.drop(columns=["TAX"])
# Out:
#      MEDV      CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD  \
# 0    24.0   0.00632  18.0   2.31   0.0  0.538  6.575   65.2  4.0900    0
# 1    21.6   0.02731   0.0   7.07   0.0  0.469  6.421   78.9  4.9671    0
# 2    34.7   0.02729   0.0   7.07   0.0  0.469  7.185   61.1  4.9671    0
# 3    33.4   0.03237   0.0   2.18   0.0  0.458  6.998   45.8  6.0622    0
# 4    36.2   0.06905   0.0   2.18   0.0  0.458  7.147   54.2  6.0622    0
# 5    28.7   0.02985   0.0   2.18   0.0  0.458  6.430   58.7  6.0622    0
# 6    22.9   0.08829  12.5   7.87   0.0  0.524  6.012   66.6  5.5605    2
# 7    27.1   0.14455  12.5   7.87   0.0  0.524  6.172   96.1  5.9505    2
# 8    16.5   0.21124  12.5   7.87   0.0  0.524  5.631  100.0  6.0821    2
# 9    18.9   0.17004  12.5   7.87   0.0  0.524  6.004   85.9  6.5921    2
# 10   15.0   0.22489  12.5   7.87   0.0  0.524  6.377   94.3  6.3467    2
# 11   18.9   0.11747  12.5   7.87   0.0  0.524  6.009   82.9  6.2267    2
# ...

# %%
# boston_df = pd.concat([boston_df, RAD_dum, TAX_dum], axis=1)
boston_df.head()
# Out:
#    MEDV     CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  PTRATIO  \
# 0  24.0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900     15.3
# 1  21.6  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671     17.8
# 2  34.7  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671     17.8
# 3  33.4  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622     18.7
# 4  36.2  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622     18.7
#
#         B  LSTAT  RAD_(0, 3]  RAD_(3, 4]  RAD_(4, 5]  RAD_(5, 24]  \
# 0  396.90   4.98           1           0           0            0
# 1  396.90   9.14           1           0           0            0
# 2  392.83   4.03           1           0           0            0
# 3  394.63   2.94           1           0           0            0
# 4  396.90   5.33           1           0           0            0
#
#    TAX_(0, 250]  TAX_(250, 350]  TAX_(350, 500]  TAX_(500, 720]
# 0             0               1               0               0
# ...

# %% [markdown]
# Note how you end up with 21 columns now!

# %% [markdown]
# ## Summary
#
# In this lab, you practiced your categorical variable knowledge on the Boston Housing Data Set!
